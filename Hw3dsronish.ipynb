# %% [markdown]
# <a href="https://colab.research.google.com/github/ronish645/rdatastruclab22/blob/main/Hw3dsronish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Q.No.1
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class CircularLinkedList:
    def __init__(self):
        self.head = None
    
    def insert(self, value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            new_node.next = self.head
        else:
            current = self.head
            while current.next != self.head:
                current = current.next
            current.next = new_node
            new_node.next = self.head
    
    def is_safe(self, n):
        current = self.head
        skip = 1
        while True:
            for i in range(skip):
                current = current.next
            skip += 1
            if current.value == 1:
                return False
            if skip > n:
                break
        return True

clist = CircularLinkedList()

for i in range(1, 11):
    clist.insert(i)

n = int(input("Enter the number of times the wolf checked: "))

safe_nests = []
for i in range(1, 11):
    if clist.is_safe(n):
        safe_nests.append(i)
    clist.head = clist.head.next

if safe_nests:
    print("Safe nests to sleep are:", safe_nests)
else:
    print("No safe nests found after the wolf checked", n, "times.")
# Out:
# Enter the number of times the wolf checked: 10
# Safe nests to sleep are: [2, 4, 7, 9]

# %%
#Q.No.2
class Node:
    def __init__(self, data=None):
        self.data = data
        self.next = None

class CircularLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
    
    def add_node(self, data):
        node = Node(data)
        if self.head is None:
            self.head = node
        else:
            self.tail.next = node
        self.tail = node
        self.tail.next = self.head

def extract_common_nodes(l: CircularLinkedList, m: CircularLinkedList) -> CircularLinkedList:
    """
    Given two circular linked lists l and m with char type node value from a-zA-Z in 
    non-descending sequence, extract common node values from both and generate a new 
    circular list without duplicated one.
    """
    common_list = CircularLinkedList()
    l_current = l.head
    m_current = m.head
    while l_current.next != l.head and m_current.next != m.head:
        if l_current.data == m_current.data:
            if common_list.head is None or common_list.tail.data != l_current.data:
                common_list.add_node(l_current.data)
            l_current = l_current.next
            m_current = m_current.next
        elif l_current.data < m_current.data:
            l_current = l_current.next
        else:
            m_current = m_current.next
    if l_current.data == m_current.data:
        if common_list.head is None or common_list.tail.data != l_current.data:
            common_list.add_node(l_current.data)
    common_list.tail.next = common_list.head
    return common_list

# Example usage
l = CircularLinkedList()
l.add_node('A')
l.add_node('C')
l.add_node('D')
l.add_node('G')
l.add_node('H')
l.add_node('J')
print("List l:")
current = l.head
while current.next != l.head:
    print(current.data, end='->')
    current = current.next
print(current.data)

m = CircularLinkedList()
m.add_node('B')
m.add_node('C')
m.add_node('F')
m.add_node('H')
m.add_node('K')
print("List m:")
current = m.head
while current.next != m.head:
    print(current.data, end='->')
    current = current.next
print(current.data)

common_list = extract_common_nodes(l, m)
print("Common List:")
current = common_list.head
while current.next != common_list.head:
    print(current.data, end='->')
    current = current.next
print(current.data)
# Out:
# List l:
# A->C->D->G->H->J
# List m:
# B->C->F->H->K
# Common List:
# C->H

# %%
#Q.No.3
class Node:
    def __init__(self, val):
        self.val = val
        self.next = None

def is_prime(num):
    """
    Returns True if num is prime, False otherwise.
    """
    if num <= 1:
        return False
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            return False
    return True

def delete_prime_CLL(m: Node) -> Node:

    # Handle empty list case
    if m is None:
        return None

    # Find the tail node
    tail = m.next
    while tail.next is not m:
        tail = tail.next

    # Traverse the list and delete prime number nodes
    cur = m.next
    prev = m
    while cur is not m:
        if is_prime(cur.val):
            prev.next = cur.next
            cur = cur.next
        else:
            prev = cur
            cur = cur.next

    # Update the tail node
    if is_prime(tail.val):
        tail = prev

    # Return the updated circular linked list
    tail.next = m
    return m

# Example usage
m = Node(None)  # Initialize head node with None value
m.next = Node(13)
m.next.next = Node(12)
m.next.next.next = Node(15)
m.next.next.next.next = Node(14)
m.next.next.next.next.next = m  # Make the list circular

print("Before deletion:")
cur = m.next
while cur is not m:
    print(cur.val, end=" ")
    cur = cur.next
print()

m = delete_prime_CLL(m)

print("After deletion:")
cur = m.next
while cur is not m:
    print(cur.val, end=" ")
    cur = cur.next
print()
# Out:
# Before deletion:
# 13 12 15 14
# After deletion:
# 12 15 14

# %%
#Q.No.4
class Node:
    def __init__(self, data=None):
        self.data = data
        self.next = None

class CircularLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
    
    def add_node(self, data):
        node = Node(data)
        if self.head is None:
            self.head = node
        else:
            self.tail.next = node
        self.tail = node
        self.tail.next = self.head
    
def split_CLL(org, N):
    new_list1 = CircularLinkedList()
    new_list2 = CircularLinkedList()
    current = org.head
    for i in range(N):
        new_list1.add_node(current.data)
        current = current.next
    new_list1.tail.next = new_list1.head
    while current != org.head:
        new_list2.add_node(current.data)
        current = current.next
    new_list2.tail.next = new_list2.head
    return new_list1, new_list2

org_list = CircularLinkedList()
org_list.add_node(2)
org_list.add_node(3)
org_list.add_node(4)
org_list.add_node(5)
org_list.add_node(6)
org_list.add_node(7)
org_list.add_node(8)

print("Original List:")
current = org_list.head
while current.next != org_list.head:
    print(current.data, end='->')
    current = current.next
print(current.data)

new_list1, new_list2 = split_CLL(org_list, 3)

print("New List 1:")
current = new_list1.head
while current.next != new_list1.head:
    print(current.data, end='->')
    current = current.next
print(current.data)

print("New List 2:")
current = new_list2.head
while current.next != new_list2.head:
    print(current.data, end='->')
    current = current.next
print(current.data)
# Out:
# Original List:
# 2->3->4->5->6->7->8
# New List 1:
# 2->3->4
# New List 2:
# 5->6->7->8

# %%
#Q.No.5
class Node:      # Define the Node class for a doubly linked list
    def __init__(self, data=None, prev=None, next=None):
        self.data = data
        self.prev = prev
        self.next = next

# Define the function to rotate a doubly linked list by N places
def rotate_DLL(head, N):
    if head is None:
        return None
    
    # Traverse to the Nth node from the head
    curr = head
    for i in range(N):
        if curr.next is None:
            return head  # N is greater than the length of the list
        curr = curr.next
        
    # Update the links to rotate the list
    new_head = curr
    new_tail = curr.prev
    while curr.next is not None:
        curr = curr.next
    curr.next = head
    head.prev = curr
    new_tail.next = None
    head = new_head
    return head

# Create a doubly linked list with nodes containing characters
head = Node('H')
node1 = Node('c')
node2 = Node('i')
node3 = Node('v')
node4 = Node('i')
node5 = Node('c')

head.next = node1
node1.prev = head
node1.next = node2
node2.prev = node1
node2.next = node3
node3.prev = node2
node3.next = node4
node4.prev = node3
node4.next = node5
node5.prev = node4

# Print the original list
print("Original List: ", end="")
curr = head.next
while curr is not None:
    print(curr.data, end=' ')
    curr = curr.next
print()

# Rotate the list by 3 places
new_head = rotate_DLL(head, 3)

# Print the rotated list
print("Rotated List: ", end="")
curr = new_head
while curr is not None:
    print(curr.data, end=' ')
    curr = curr.next
print()
# Out:
# Original List: c i v i c
# Rotated List: v i c H c i

# %%
#Q.No.6
class Node:
    def __init__(self, val):
        self.val = val
        self.next = None
        self.prev = None
        self.random = None

def correct_random_ptrs(head):
    if not any(node.random for node in iterate_list(head)):
        return head

    node_map = {}
    new_head = None
    curr = head

    while curr:
        node_map[curr] = Node(curr.val)
        if not new_head:
            new_head = node_map[curr]
        if curr.prev:
            node_map[curr.prev].next = node_map[curr]
        if curr.next:
            node_map[curr.next].prev = node_map[curr]
        curr = curr.next

    curr = head
    while curr:
        node_map[curr].random = node_map[curr.random] if curr.random else None
        curr = curr.next

    return new_head

def iterate_list(head):
    curr = head
    while curr:
        yield curr
        curr = curr.next
